# %%
import os

# %%
pip install nltk

# %%
import nltk
nltk.download()
# Out:
# showing info https://raw.githubusercontent.com/nltk/nltk_data/gh-pages/index.xml
# True

# %%
os.getcwd()
os.chdir('C:/Users/muham/OneDrive/Desktop/GMU/NLP/files')
os.getcwd()
# Out:
# 'C:\\Users\\muham\\OneDrive\\Desktop\\GMU\\NLP\\files'

# %%
textfile = open('Hp.txt', mode='r', encoding='utf-8')
allwords = textfile.read()
print(allwords[:500])
# Out:
# Harry Potter and the Sorcerer's Stone
#
# CHAPTER ONE
#
# THE BOY WHO LIVED
#
# Mr. and Mrs. Dursley, of number four, Privet Drive, were proud to say that they were perfectly normal, thank you very much. They were the last people you'd expect to be involved in anything strange or mysterious, because they just didn't hold with such nonsense.
#
# Mr. Dursley was the director of a firm called Grunnings, which made drills. He was a big, beefy man with hardly any neck, although he did have a very large musta

# %%
from nltk.corpus import words

# %%
nltk.download('words')
# Out:
# [nltk_data] Downloading package words to
# [nltk_data]     C:\Users\muham\AppData\Roaming\nltk_data...
# [nltk_data]   Package words is already up-to-date!
# True

# %%
from nltk.tokenize import RegexpTokenizer
tokenizer = RegexpTokenizer(r'\w+')
tokens = tokenizer.tokenize(allwords)
print(tokens[:20])
# Out:
# ['Harry', 'Potter', 'and', 'the', 'Sorcerer', 's', 'Stone', 'CHAPTER', 'ONE', 'THE', 'BOY', 'WHO', 'LIVED', 'Mr', 'and', 'Mrs', 'Dursley', 'of', 'number', 'four']

# %%
from nltk.tokenize import sent_tokenize,word_tokenize
word_tokenize(allwords)
print(len(word_tokenize(allwords)))
# Out:
# 98781

# %%
print(len(tokens))
# Out:
# 80646

# %%
sentences = nltk.sent_tokenize(allwords)
for s in sentences: print(s)
# Out:
# Harry Potter and the Sorcerer's Stone
#
# CHAPTER ONE
#
# THE BOY WHO LIVED
#
# Mr. and Mrs. Dursley, of number four, Privet Drive, were proud to say that they were perfectly normal, thank you very much.
# They were the last people you'd expect to be involved in anything strange or mysterious, because they just didn't hold with such nonsense.
# Mr. Dursley was the director of a firm called Grunnings, which made drills.
# He was a big, beefy man with hardly any neck, although he did have a very large mustache.
# Mrs. Dursley was thin and blonde and had nearly twice the usual amount of neck, which came in very useful as she spent so much of her time craning over garden fences, spying on the neighbors.
# The Dursleys had a small son called Dudley and in their opinion there was no finer boy anywhere.
# The Dursleys had everything they wanted, but they also had a secret, and their greatest fear was that somebody would discover it.
# ...

# %%
print('no of Sentences',len(sentences))
# Out:
# no of Sentences 6394

# %%
words = nltk.word_tokenize(allwords)
print('no of words',len(words))
# Out:
# no of words 98781

# %%
print(words[0:20])
# Out:
# ['Harry', 'Potter', 'and', 'the', 'Sorcerer', "'s", 'Stone', 'CHAPTER', 'ONE', 'THE', 'BOY', 'WHO', 'LIVED', 'Mr.', 'and', 'Mrs.', 'Dursley', ',', 'of', 'number']

# %%
from nltk.tokenize import RegexpTokenizer
tokenizer = RegexpTokenizer(r'\w+')
tokens = tokenizer.tokenize(allwords)
print(tokens[:20])
# Out:
# ['Harry', 'Potter', 'and', 'the', 'Sorcerer', 's', 'Stone', 'CHAPTER', 'ONE', 'THE', 'BOY', 'WHO', 'LIVED', 'Mr', 'and', 'Mrs', 'Dursley', 'of', 'number', 'four']

# %%
print('no of words without punctuation',len(tokens))
# Out:
# no of words without punctuation 80646

# %%
from nltk.corpus import stopwords
sw = stopwords.words('english')
Without_sw = [token for token in tokens if token not in sw]
print(Without_sw[0:20])
# Out:
# ['Harry', 'Potter', 'Sorcerer', 'Stone', 'CHAPTER', 'ONE', 'THE', 'BOY', 'WHO', 'LIVED', 'Mr', 'Mrs', 'Dursley', 'number', 'four', 'Privet', 'Drive', 'proud', 'say', 'perfectly']

# %%
print('no of words without stop words',len(Without_sw))
freq_dist = nltk.FreqDist(Without_sw)
print(freq_dist)
# Out:
# no of words without stop words 45253
# <FreqDist with 6506 samples and 45253 outcomes>

# %%
from nltk.stem import WordNetLemmatizer
lemmatizer = WordNetLemmatizer()

# %%
Lemmatize = []
for token in tokens:
    Lemmatize.append(lemmatizer.lemmatize(token))
print(len(Lemmatize))    
freq_dist = nltk.FreqDist(Lemmatize)
print(freq_dist)
# Out:
# 45253
# <FreqDist with 6021 samples and 45253 outcomes>

# %%
print(Lemmatize[0:20])
# Out:
# ['Harry', 'Potter', 'Sorcerer', 'Stone', 'CHAPTER', 'ONE', 'THE', 'BOY', 'WHO', 'LIVED', 'Mr', 'Mrs', 'Dursley', 'number', 'four', 'Privet', 'Drive', 'proud', 'say', 'perfectly']

# %% [markdown]
# For the Stopwords and lemmatize the no of outcome remain same but sample of frequency for lemmatize decreases by 500 samples as lematize remove extra characters from words where as stop words dont.

# %%
print(freq_dist.most_common(15))
# Out:
# [('Harry', 1326), ('I', 924), ('said', 793), ('He', 549), ('Ron', 429), ('Hagrid', 370), ('The', 297), ('It', 286), ('Hermione', 270), ('back', 261), ('one', 244), ('know', 206), ('get', 192), ('could', 190), ('like', 190)]

# %%
freq_dist.plot(15)
# Out:
# <AxesSubplot:xlabel='Samples', ylabel='Counts'>

# %%
from wordcloud import WordCloud

# %%
import matplotlib.pyplot as plt

# %%
wordcloud = WordCloud(stopwords=sw).generate(allwords)
plt.figure()
plt.imshow(wordcloud, interpolation='bilinear')

# %%
wordcloud2=WordCloud().generate_from_frequencies(freq_dist)

# %%
plt.figure()
plt.imshow(wordcloud2, interpolation='bilinear')

# %% [markdown]
# First Word cloud is showing number of times each word appears in a document.
# Second word cloud is showing each word that is appearing as relative to another words in a document

# %% [markdown]
# Numeric Data Processing
# Collect, extract, transform and load data into a data warehouse.
# Store and manage the data, multidimensional database i.e. either on in-house servers or the cloud.
# Provide data access to business analysts, management teams, and information technology professionals and determine how they want to organize it using application software.
# And finally, present the data in an easy to share formats, such as a table or graph.
# Text Data Processing
# The text mining requires both sophisticated linguistic and statistical techniques able to analyze unstructured text formats and techniques that combine each document with actionable metadata, which can be considered a sort of anchor in structuring this type of data.
#
# Text mining consists of a broad variety of methods and technologies such as:
#
# Keyword-based technologies: The input is based on a selection of keywords in the text that are filtered as a series of character strings, not words nor “concepts”.
# Statistics technologies: Refers to systems based on machine learning. Statistics technologies leverage a training set of documents used as a model to manage and categorize text.
# Linguistic-based technologies: This method may leverage language processing systems. The output of text analysis allows a shallow understanding of the structure of the text, the grammar and logic employed. (For a better understanding of how this works, this post on text mining and NLP is helpful.)
# All these approaches have a common feature, that they are all concerned with processing text in an approximate way whereas they are not capable to understand them.
